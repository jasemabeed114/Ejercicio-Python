# %%
import json
def return_cabeceras(data,cabecera):
    name=[]
    for x in data:
        name.append(x[cabecera])
    return name
        

def todos_valores(data):
    return data

data = [
      {
        "id": "0001",
        "name": "Jose Alberto",
        "last_name": "Escalona",
        "startDate": "8-04-2021",
        "work": "Chedraui"
      },
      {
        "id": "0002",
        "name": "Nadia",
        "last_name": "Buendia",
        "startDate": "03-04-2021",
        "work": "Walmart"
      },
      {
        "id": "0003",
        "name": "Pablo Saul",
        "last_name": "Ramirez",
        "startDate": "01-04-2020",
        "work": "GoNet"
      },
      {
        "id": "0004",
        "name": "Santiago",
        "last_name": "Perea",
        "startDate": "02-12-2021",
        "work": "Devlyn"
      },
      {
        "id": "0005",
        "name": "Brenda",
        "last_name": "Samperio",
        "startDate": "03-04-2021",
        "work": "Walmart"
      }
    ];
    
    
    
    
    
todos=todos_valores(data)
cabecera="work"
por_cabecera=return_cabeceras(data,cabecera)
print("********")
print("Todos los valores")
print(todos)
print("********")
print("********")
print("Por cabeceras")
print(por_cabecera)
print("********")

print("Salida Json")
print(json.dumps(todos))
print(json.dumps(por_cabecera))
print("********")
# Out:
# ********
# Todos los valores
# [{'id': '0001', 'name': 'Jose Alberto', 'last_name': 'Escalona', 'startDate': '8-04-2021', 'work': 'Chedraui'}, {'id': '0002', 'name': 'Nadia', 'last_name': 'Buendia', 'startDate': '03-04-2021', 'work': 'Walmart'}, {'id': '0003', 'name': 'Pablo Saul', 'last_name': 'Ramirez', 'startDate': '01-04-2020', 'work': 'GoNet'}, {'id': '0004', 'name': 'Santiago', 'last_name': 'Perea', 'startDate': '02-12-2021', 'work': 'Devlyn'}, {'id': '0005', 'name': 'Brenda', 'last_name': 'Samperio', 'startDate': '03-04-2021', 'work': 'Walmart'}]
# ********
# ********
# Por cabeceras
# ['Chedraui', 'Walmart', 'GoNet', 'Devlyn', 'Walmart']
# ********
# Salida Json
# ...
